# %%
# Initial imports
import pandas as pd
from sklearn.cluster import KMeans
import plotly.express as px
import hvplot.pandas

# %%
# Load data
file_path = "archive/more song data.csv"
df_music = pd.read_csv(file_path)
df_music.head(10)
# Out:
#    musicid                                       title         artist  \
# 0        1                            Hey, Soul Sister          Train
# 1        2                        Love The Way You Lie         Eminem
# 2        3                                     TiK ToK          Kesha
# 3        4                                 Bad Romance      Lady Gaga
# 4        5                        Just the Way You Are     Bruno Mars
# 5        6                                        Baby  Justin Bieber
# 6        7                                    Dynamite      Taio Cruz
# 7        8                                     Secrets    OneRepublic
# 8        9  Empire State of Mind (Part II) Broken Down    Alicia Keys
# 9       10                    Only Girl (In The World)        Rihanna
#
#              genre  songyear  bpm  energy  danceability  loudness  liveness  \
# 0       neo mellow      2010   97      89            67        -4         8
# ...

# %%
sorted_df = df_music.sort_values('popularity', ascending = False)
sorted_df.head()
# Out:
#      musicid                title         artist         genre  songyear  bpm  \
# 572      573             Memories       Maroon 5           pop      2019   91
# 573      574  Lose You To Love Me   Selena Gomez     dance pop      2019  102
# 574      575    Someone You Loved  Lewis Capaldi           pop      2019  110
# 575      576             Seёorita   Shawn Mendes  canadian pop      2019  117
# 576      577    How Do You Sleep?      Sam Smith           pop      2019  111
#
#      energy  danceability  loudness  liveness  valence  duration  \
# 572      32            76        -7         8       57       189
# 573      34            51        -9        21        9       206
# 574      41            50        -6        11       45       182
# 575      54            76        -6         9       75       191
# 576      68            48        -5         8       35       202
#
#      acounticness  speechiness  popularity
# 572            84            5          99
# ...
